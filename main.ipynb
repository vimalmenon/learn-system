# %%
def test():
    print("Hello, World!")


test()
# Out:
# Hello, World!

# %%
a = [1 , 2, 3, 4, 5]
b = [5, 6, 7, 8, 9]

print(a + b)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9]

# %%
import requests

async def test():
    print("This is an async test function.")
    response = requests.get('https://api.github.com')

    print(response.status_code)
    print(response.json())

await test()
# Out:
# This is an async test function.
# 200
# ...

# %%
def test(items = None) -> None:
    if items is None:
        items = []
    print(items)

test();
# Out:
# []

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

json_data = [
    {"name": "Alice", "age": 30},
    {"name": "Bob", "age": 25},
    {"name": "Charlie", "age": 35},
    {"name": "David", "age": 40},
]
df = pd.DataFrame(json_data)

print(df)
print("-------")
print(df[df['age'] > 30])
print("-------")
print(df.loc[df['age'] > 30]['name'])
print("-------")
print(df.iloc[2].get('test'))
# Out:
#       name  age
# 0    Alice   30
# 1      Bob   25
# 2  Charlie   35
# 3    David   40
# -------
#       name  age
# 2  Charlie   35
# 3    David   40
# -------
# 2    Charlie
# 3      David
# Name: name, dtype: str
# -------
# None

# %%
print(df.to_dict(orient='records')[0])
# Out:
# {'name': 'Alice', 'age': 30}

# %%
from typing import Protocol


class MyProtocol(Protocol):
    def my_method(self) -> str:
        ...

# %%
from functools import lru_cache
from contextlib import contextmanager
import time

try:
    from tools import measure_time
except ModuleNotFoundError:
    @contextmanager
    def measure_time():
        start = time.perf_counter()
        try:
            yield
        finally:
            elapsed = time.perf_counter() - start
            print(f"Elapsed time: {elapsed:.6f} seconds")


@lru_cache(maxsize=32)
def fibonacci(n: int) -> int:
    if n < 2:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

with measure_time():
    fib = fibonacci(10)
    print(fib)
with measure_time():
    fib = fibonacci(10)
    print(fib)
with measure_time():
    fib = fibonacci(100)
    print(fib)
# Out:
# 55
# Elapsed time: 0.000150 seconds
# 55
# Elapsed time: 0.000005 seconds
# 354224848179261915075
# Elapsed time: 0.000039 seconds

# %%
from abc import ABC, abstractmethod
from typing import Self

class Test(ABC):
    @abstractmethod
    def my_method(self) -> str:
        pass

    @classmethod
    def to_cls(cls) -> Self:
        return cls()

class MyTest(Test):
    def my_method(self) -> str:
        return "Hello from MyTest!"


def main():
    my_test = MyTest.to_cls()
    print(my_test.my_method())

main()
# Out:
# Hello from MyTest!

# %%
sample_dict = [
    {"name": "Alice", "age": 30, "gender": "F", "profession": "Data Analyst", "country": "USA", "working": True},
    {"name": "Bob", "age": 27, "gender": "M", "profession": "Software Engineer", "country": "Canada", "working": True},
    {"name": "Charlie", "age": 35, "gender": "M", "profession": "Teacher", "country": "Germany", "working": True},
    {"name": "Diana", "age": 29, "gender": "F", "profession": "Nurse", "country": "Brazil", "working": True},
    {"name": "Ethan", "age": 41, "gender": "M", "profession": "Doctor", "country": "UK", "working": True},
    {"name": "Fiona", "age": 32, "gender": "F", "profession": "Designer", "country": "France", "working": False},
    {"name": "Gabriel", "age": 26, "gender": "M", "profession": "Developer", "country": "Spain", "working": True},
    {"name": "Hannah", "age": 24, "gender": "F", "profession": "Marketing Specialist", "country": "Australia", "working": True},
    {"name": "Isaac", "age": 38, "gender": "M", "profession": "Accountant", "country": "Japan", "working": True},
    {"name": "Julia", "age": 31, "gender": "F", "profession": "Researcher", "country": "India", "working": False},
    {"name": "Kevin", "age": 45, "gender": "M", "profession": "Manager", "country": "Mexico", "working": True},
    {"name": "Laura", "age": 33, "gender": "F", "profession": "Writer", "country": "Argentina", "working": True},
    {"name": "Mason", "age": 28, "gender": "M", "profession": "Electrician", "country": "Italy", "working": True},
    {"name": "Nora", "age": 36, "gender": "F", "profession": "HR Specialist", "country": "South Korea", "working": True},
    {"name": "Owen", "age": 40, "gender": "M", "profession": "Engineer", "country": "Germany", "working": True},
    {"name": "Priya", "age": 27, "gender": "F", "profession": "Product Manager", "country": "India", "working": True},
    {"name": "Quinn", "age": 29, "gender": "M", "profession": "Photographer", "country": "Canada", "working": False},
    {"name": "Ruby", "age": 34, "gender": "F", "profession": "Lawyer", "country": "USA", "working": True},
    {"name": "Samuel", "age": 42, "gender": "M", "profession": "Consultant", "country": "UAE", "working": True},
    {"name": "Tessa", "age": 25, "gender": "F", "profession": "Graphic Designer", "country": "France", "working": True},
    {"name": "Uma", "age": 39, "gender": "F", "profession": "Scientist", "country": "Norway", "working": False},
    {"name": "Victor", "age": 31, "gender": "M", "profession": "Chef", "country": "Brazil", "working": True},
    {"name": "Wendy", "age": 44, "gender": "F", "profession": "Finance Manager", "country": "UK", "working": True},
    {"name": "Xavier", "age": 46, "gender": "M", "profession": "Pilot", "country": "Australia", "working": True},
    {"name": "Yara", "age": 28, "gender": "F", "profession": "Architect", "country": "Egypt", "working": True},
    {"name": "Zack", "age": 33, "gender": "M", "profession": "Mechanic", "country": "Germany", "working": False},
    {"name": "Ava", "age": 30, "gender": "F", "profession": "Biologist", "country": "Canada", "working": True},
    {"name": "Ben", "age": 37, "gender": "M", "profession": "Sales Representative", "country": "USA", "working": True},
    {"name": "Chloe", "age": 26, "gender": "F", "profession": "Journalist", "country": "Spain", "working": False},
    {"name": "Daniel", "age": 43, "gender": "M", "profession": "Civil Engineer", "country": "Mexico", "working": True},
    {"name": "Emma", "age": 35, "gender": "F", "profession": "Operations Manager", "country": "France", "working": True},
    {"name": "Felix", "age": 29, "gender": "M", "profession": "Web Developer", "country": "Sweden", "working": True},
    {"name": "Grace", "age": 32, "gender": "F", "profession": "Pharmacist", "country": "India", "working": True},
    {"name": "Henry", "age": 41, "gender": "M", "profession": "Logistics Coordinator", "country": "Germany", "working": True},
    {"name": "Iris", "age": 27, "gender": "F", "profession": "Social Worker", "country": "Brazil", "working": False},
    {"name": "Jack", "age": 34, "gender": "M", "profession": "Programmer", "country": "USA", "working": True},
    {"name": "Kate", "age": 38, "gender": "F", "profession": "Economist", "country": "UK", "working": True},
    {"name": "Leo", "age": 31, "gender": "M", "profession": "Security Analyst", "country": "Canada", "working": True},
    {"name": "Mia", "age": 29, "gender": "F", "profession": "Event Planner", "country": "Italy", "working": True},
    {"name": "Noah", "age": 36, "gender": "M", "profession": "Mechanical Engineer", "country": "Japan", "working": True},
    {"name": "Olivia", "age": 24, "gender": "F", "profession": "Student", "country": "Germany", "working": False},
    {"name": "Peter", "age": 45, "gender": "M", "profession": "Entrepreneur", "country": "UAE", "working": True},
    {"name": "Quinn", "age": 33, "gender": "F", "profession": "UX Designer", "country": "Australia", "working": True},
    {"name": "Ryan", "age": 28, "gender": "M", "profession": "Statistician", "country": "New Zealand", "working": False},
    {"name": "Sara", "age": 40, "gender": "F", "profession": "Veterinarian", "country": "USA", "working": True},
    {"name": "Tom", "age": 32, "gender": "M", "profession": "Construction Manager", "country": "Spain", "working": True},
    {"name": "Uma", "age": 26, "gender": "F", "profession": "Fashion Designer", "country": "India", "working": True},
    {"name": "Vince", "age": 48, "gender": "M", "profession": "Lawyer", "country": "Canada", "working": True},
    {"name": "Willow", "age": 30, "gender": "F", "profession": "Project Manager", "country": "France", "working": True},
    {"name": "Zach", "age": 27, "gender": "M", "profession": "Data Scientist", "country": "Brazil", "working": True},
]

print(sample_dict)
# Out:
# [{'name': 'Alice', 'age': 30, 'gender': 'F', 'profession': 'Data Analyst', 'country': 'USA', 'working': True}, {'name': 'Bob', 'age': 27, 'gender': 'M', 'profession': 'Software Engineer', 'country': 'Canada', 'working': True}, {'name': 'Charlie', 'age': 35, 'gender': 'M', 'profession': 'Teacher', 'country': 'Germany', 'working': True}, {'name': 'Diana', 'age': 29, 'gender': 'F', 'profession': 'Nurse', 'country': 'Brazil', 'working': True}, {'name': 'Ethan', 'age': 41, 'gender': 'M', 'profession': 'Doctor', 'country': 'UK', 'working': True}, {'name': 'Fiona', 'age': 32, 'gender': 'F', 'profession': 'Designer', 'country': 'France', 'working': False}, {'name': 'Gabriel', 'age': 26, 'gender': 'M', 'profession': 'Developer', 'country': 'Spain', 'working': True}, {'name': 'Hannah', 'age': 24, 'gender': 'F', 'profession': 'Marketing Specialist', 'country': 'Australia', 'working': True}, {'name': 'Isaac', 'age': 38, 'gender': 'M', 'profession': 'Accountant', 'country': 'Japan', 'working': Tr
# ...

# %%
import pandas as pd

df = pd.DataFrame(sample_dict)

# print(df)

# print(df.loc[df['age'] > 30])
# print(df.loc[df['age'] > 30, ["name", "age", "profession"]])
# print(df.loc[df['age'] > 30, ["name", "age", "profession"]])

df_country = df.groupby("country")

print(df_country.groups)
# Out:
# {'Argentina': [11], 'Australia': [7, 23, 42], 'Brazil': [3, 21, 34, 49], 'Canada': [1, 16, 26, 37, 47], 'Egypt': [24], 'France': [5, 19, 30, 48], 'Germany': [2, 14, 25, 33, 40], 'India': [9, 15, 32, 46], 'Italy': [12, 38], 'Japan': [8, 39], 'Mexico': [10, 29], 'New Zealand': [43], 'Norway': [20], 'South Korea': [13], 'Spain': [6, 28, 45], 'Sweden': [31], 'UAE': [18, 41], 'UK': [4, 22, 36], 'USA': [0, 17, 27, 35, 44]}
